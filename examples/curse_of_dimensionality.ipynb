# %% [markdown]
# # Curse of Dimensionality
#
# This notebook demonstrates the curse of dimensionality.
#
# ## Distances

# %%
# %matplotlib inline
from lib import YouTube
import matplotlib.pyplot as plt
import numpy as np
import numpy.random
import numpy.linalg

def sample(dim, count=500):
    """Generate data sample."""
    return np.random.normal(0, 1, (count, dim))

def scatter2d(data):
    """Show 2D scatter plot."""
    fig = plt.figure(figsize=(5, 5), dpi=80)
    axes = fig.gca()
    axes.set_aspect('equal', adjustable='box')
    axes.scatter(data[:, 0], data[:, 1], alpha=0.5)

def scatter3d(data):
    """Show 3D scatter plot."""
    fig = plt.figure(figsize=(8, 8), dpi=80)
    axes = fig.add_subplot(projection='3d')
    axes.scatter(data[:, 0], data[:, 1], data[:, 2], alpha=0.5)

# %%
scatter2d(sample(2, 500))

# %%
scatter3d(sample(3, 500))

# %%
def distances(data):
    """Get pairwise distances."""
    return np.array([np.linalg.norm(u-v) for u in data for v in data if (u != v).any()])


plt.hist(distances(sample(400)), bins=50, range=(0, 40))
# Out:
# (array([0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.4000e+01, 5.8200e+02, 5.7660e+03, 2.7444e+04, 6.4434e+04,
#         7.8768e+04, 5.0480e+04, 1.7964e+04, 3.5980e+03, 4.3600e+02,
#         1.0000e+01, 4.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00]),
#  array([ 0. ,  0.8,  1.6,  2.4,  3.2,  4. ,  4.8,  5.6,  6.4,  7.2,  8. ,
#          8.8,  9.6, 10.4, 11.2, 12. , 12.8, 13.6, 14.4, 15.2, 16. , 16.8,
#         17.6, 18.4, 19.2, 20. , 20.8, 21.6, 22.4, 23.2, 24. , 24.8, 25.6,
#         26.4, 27.2, 28. , 28.8, 29.6, 30.4, 31.2, 32. , 32.8, 33.6, 34.4,
#         35.2, 36. , 36.8, 37.6, 38.4, 39.2, 40. ]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# ## Credits
#
# The example is borrowed from the _UMAP Uniform Manifold Approximation and Projection for Dimension Reduction | SciPy 2018_ talk by [Leland McInnes](https://github.com/lmcinnes).
#
# Time code: `11:15`

# %%
YouTube("nq6iPZVUxZU")
# Out:
#         <iframe
#             width="560"
#             height="316"
#             src="https://www.youtube.com/embed/nq6iPZVUxZU"
#             title="YouTube video player"
#             frameborder="0"
#             allow="accelerometer;
#             autoplay;
#             clipboard-write;
#             encrypted-media;
#             gyroscope;
#             picture-in-picture"
#             allowfullscreen>
#         </iframe>
