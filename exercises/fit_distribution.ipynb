# %% [markdown]
# # Fitting Distribution to Empirical Data
#
# This notebook demonstrates fitting of well-known distributions from `scipy` library to empirical data.

# %% [markdown]
# ## Generate Data

# %%
from scipy.stats import chi2, lognorm
import matplotlib.pyplot as plt
import seaborn as sns

x = lognorm.rvs(s=0.7, loc=0, scale=15000, size=1000000)
_ = plt.hist(x, bins=100, log=True)
